# %%
# !pip install PyDrive
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from google.colab import files
from google.colab import auth
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials

# %%
#Authenticating User for PyDrive
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Downloading Finance Data
id = '1iGPSKLxA_myWDzKwtPKSnAXx9V5B8AMS' # https://drive.google.com/file/d/1iGPSKLxA_myWDzKwtPKSnAXx9V5B8AMS/view?usp=sharing
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('S&PFinanceData.csv')  
df = pd.read_csv('S&PFinanceData.csv', parse_dates = True)
df.head
# Out:
# <bound method NDFrame.head of            Date         Open         High  ...        Close    Adj Close      Volume
# 0    2019-01-02  2476.959961  2519.489990  ...  2510.030029  2510.030029  3733160000
# 1    2019-01-03  2491.919922  2493.139893  ...  2447.889893  2447.889893  3822860000
# 2    2019-01-04  2474.330078  2538.070068  ...  2531.939941  2531.939941  4213410000
# 3    2019-01-07  2535.610107  2566.159912  ...  2549.689941  2549.689941  4104710000
# 4    2019-01-08  2568.110107  2579.820068  ...  2574.409912  2574.409912  4083030000
# ..          ...          ...          ...  ...          ...          ...         ...
# 98   2019-05-23  2836.699951  2836.699951  ...  2822.239990  2822.239990  3891980000
# 99   2019-05-24  2832.409912  2841.360107  ...  2826.060059  2826.060059  2887390000
# 100  2019-05-28  2830.030029  2840.510010  ...  2802.389893  2802.389893  4121410000
# 101  2019-05-29  2790.250000  2792.030029  ...  2783.020020  2783.020020  3700050000
# ...

# %%
#Plotting Finance Data
plt.style.use("ggplot")
df['Open'].plot()
plt.xlabel('Days Since 01-01-2019')
plt.ylabel('Dollars ($)')
plt.title('Stock Prices for S&P 500')
# Out:
# Text(0.5, 1.0, 'Stock Prices for S&P 500')
